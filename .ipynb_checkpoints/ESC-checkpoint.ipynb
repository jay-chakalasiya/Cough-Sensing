# %%
import os
import pandas as pd
import librosa
import IPython.display as ipd
import librosa.display
import matplotlib.pyplot as plt
len(os.listdir('ESC-50-master/audio'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-b785e875d01e> in <module>
#       5 import librosa.display
#       6 import matplotlib.pyplot as plt
# ----> 7 len(os.listdir('ESC-50-master/audio'))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'ESC-50-master/audio'

# %%
DF = pd.read_csv('ESC-50-master/meta/esc50.csv')
DF[DF.category=='dog']
# Out:
#               filename  fold  target category  esc10  src_file take
# 0     1-100032-A-0.wav     1       0      dog   True    100032    A
# 14    1-110389-A-0.wav     1       0      dog   True    110389    A
# 157    1-30226-A-0.wav     1       0      dog   True     30226    A
# 158    1-30344-A-0.wav     1       0      dog   True     30344    A
# 170    1-32318-A-0.wav     1       0      dog   True     32318    A
# 296    1-59513-A-0.wav     1       0      dog   True     59513    A
# 375    1-85362-A-0.wav     1       0      dog   True     85362    A
# 392    1-97392-A-0.wav     1       0      dog   True     97392    A
# 478   2-114280-A-0.wav     2       0      dog   True    114280    A
# 479   2-114587-A-0.wav     2       0      dog   True    114587    A
# 482   2-116400-A-0.wav     2       0      dog   True    116400    A
# 484   2-117271-A-0.wav     2       0      dog   True    117271    A
# 496   2-118072-A-0.wav     2       0      dog   True    118072    A
# ...

# %%
plt.figure(figsize=(15,4))
data,sample_rate = librosa.load('ESC-50-master/audio/1-30226-A-0.wav', sr=22050, mono=True, offset=0.0, duration=50, res_type='kaiser_best')
librosa.display.waveplot(data,sr=sample_rate, max_points=50000.0, x_axis='time', offset=0.0, max_sr=1000)

# %%
data.shape
# Out:
# (110250,)
